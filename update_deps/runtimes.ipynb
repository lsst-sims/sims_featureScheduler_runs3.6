# %%
import numpy as np
import healpy as hp
import matplotlib.pylab as plt
# %matplotlib inline

# %%
times = [5,10,41]
pix = hp.nside2npix(np.array([32,64,128]))

# %%
plt.plot(pix, times, 'ko')
plt.xlabel('N HEALpix')
plt.ylabel('Runtime (minutes)')
# Out:
# Text(0, 0.5, 'Runtime (minutes)')
